# %%
from tkinter import *
def click(event):
    global scvalue
    text=event.widget.cget("text")
    print(text)
    if text=="=":
        if scvalue.get().isdigit():
            value=int(scvalue.get())
        else:
            try:
                value=eval(screen.get())
            except Exception as e:
                print(e)
                value="Error"
                
        scvalue.set(value)
        screen.update()
    elif text=="c":
        scvalue.set("")
        screen.update()
    else:
        scvalue.set(scvalue.get() +text)
        screen.update()
        
window=Tk()
window.geometry("650x900")
window.title("Calculater")
scvalue=StringVar()
scvalue.set("")
screen=Entry(textvar=scvalue,font="lucida 40 bold")
screen.pack()
button=Button(text="9",font="lucida 35 bold",height=1,width=2)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=60, y=120)
button=Button(text="8",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=150, y=120)
button=Button(text="7",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=240, y=120)
button=Button(text="6",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=60, y=230)
button=Button(text="5",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=240, y=230)
button=Button(text="4",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=150, y=230)
button=Button(text="3",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=8)
button.bind("<Button-1>",click)
button.place(x=60, y=340)
button=Button(text="2",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=150, y=340)
button=Button(text="1",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=240, y=340)
button=Button(text="0",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=150, y=450)
button=Button(text="+",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=60, y=450)
button=Button(text="-",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=240, y=450)
button=Button(text="=",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=240, y=560)
button=Button(text="*",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=60, y=560)
button=Button(text="/",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=150, y=560)
button=Button(text="c",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=330, y=120)
button=Button(text=".",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=330, y=230)
button=Button(text="00",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=330, y=340)
button=Button(text="%",font="lucida 35 bold",height=1,width=2,padx=0,pady=1)
button.pack(side=LEFT,padx=18,pady=12)
button.bind("<Button-1>",click)
button.place(x=330, y=450)
window.mainloop()
# Out:
# 7
# 5
# +
# 3
# 2
# =
# c
# 1
# 5
# 5
# 5
# 5
# 1
# 2
# +
# 0
# 0
# 0
# =
